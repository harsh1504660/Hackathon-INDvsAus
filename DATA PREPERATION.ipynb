# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_zpyYWs0.csv')

# %%
df.head()
# Out:
#    player_id   player_name runs_scored wickets runs_conceded catches  \
# 0          1   Pat Cummins         DNB       3            28       0
# 1          2   Steve Smith         DNB       -             -       0
# 2         10   Mitch Marsh          8*       1            19       1
# 3         13  David Warner          20       -             -       0
# 4          1   Pat Cummins         11*       1            73       0
#
#   stumpings   match_date                opposition  match_id
# 0         0  19 Oct 2011  v South Africa Centurion         1
# 1         0  19 Oct 2011  v South Africa Centurion         1
# 2         0  19 Oct 2011  v South Africa Centurion         1
# 3         0  19 Oct 2011  v South Africa Centurion         1
# 4         0  23 Oct 2011   v South Africa Gqeberha         2

# %%
df.shape
# Out:
# (2575, 10)

# %%
df['player_name'].unique()
# Out:
# array(['Pat Cummins', 'Steve Smith', 'Mitch Marsh', 'David Warner',
#        'Glenn Maxwell', 'Mitchell Starc.', 'Josh Hazlewood',
#        'Rohit Sharma', 'Virat Kohli', 'Mohammed Shami',
#        'Ravichandran Ashwin', 'Marcus Stoinis', 'Travis Head',
#        'Adam Zampa', 'Hardik Pandya', 'Jasprit Bumrah', 'Kuldeep Yadav',
#        'Alex Carey', 'Ravindra Jadeja', 'KL Rahul', 'Marnus Labuschagne',
#        'Shreyas Iyer', 'Shardul Thakur', 'Cameron Green', 'Josh Inglis',
#        'Sean Abbott', 'Shubman Gill', 'Ishan Kishan', 'Suryakumar Yadav',
#        'Mohammed Siraj'], dtype=object)

# %%
df['match_date'].unique()
# Out:
# array(['19 Oct 2011', '23 Oct 2011', '28 Oct 2011', '23 Jun 2012',
#        '29 Jun 2012', '21 Nov 2014', '23 Nov 2014', '16 Jan 2015',
#        '18 Jan 2015', '23 Jan 2015', '28 Feb 2015', '14 Mar 2015',
#        '27 Aug 2015', '3 Sep 2015', '5 Sep 2015', '8 Sep 2015',
#        '11 Sep 2015', '13 Sep 2015', '4 Dec 2016', '6 Dec 2016',
#        '9 Dec 2016', '13 Jan 2017', '15 Jan 2017', '19 Jan 2017',
#        '22 Jan 2017', '26 Jan 2017', '30 Jan 2017', '5 Feb 2017',
#        '2 Jun 2017', '5 Jun 2017', '10 Jun 2017', '17 Sep 2017',
#        '21 Sep 2017', '24 Sep 2017', '28 Sep 2017', '1 Oct 2017',
#        '14 Jan 2018', '21 Jan 2018', '26 Jan 2018', '4 Nov 2018',
#        '9 Nov 2018', '11 Nov 2018', '2 Mar 2019', '5 Mar 2019',
#        '8 Mar 2019', '10 Mar 2019', '13 Mar 2019', '27 Mar 2019',
#        '1 Jun 2019', '6 Jun 2019', '9 Jun 2019', '12 Jun 2019',
#        '15 Jun 2019', '20 Jun 2019', '25 Jun 2019', '29 Jun 2019',
# ...

# %%
bat = pd.read_csv('bat.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bat = pd.read_csv('bat.csv')
#
# File E:\anaconda\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
# ...

# %%
ball = pd.read_csv('ball.csv')

# %%
match = pd.read_csv('match.csv')

# %%
bat.head()

# %%
bat['runs_x'].max()

# %%
bat['runs_y'].max()

# %%
bat.columns

# %%
bat.drop(columns=['Unnamed: 0','id','fall_of_wicket_over','how_out','match_number','series_id','opp_team_id','team_id'],axis=1,inplace=True)

# %%
bat.head()

# %%
bat.drop(columns=['fours','sixes','fall_of_wicket','player_id','scorecard_id','match_detail_id','match_id'],inplace=True,axis=1)

# %%
bat.head()

# %%
bat.shape

# %%
bat['team_id'].unique()
# Out:
# array([ 7,  2,  9,  8,  3,  4, 10,  6,  5, 15, 11,  1, 16, 41, 42, 12, 17,
#        18, 24, 26, 20, 25, 22, 27, 31, 21, 19, 13, 32, 30, 33, 34, 35, 36,
#        38, 37, 39, 40, 23, 14, 28, 29, 43], dtype=int64)

# %%
bat[bat['matchtype'] =='odi'].shape
# Out:
# (16394, 28)

# %%
for i in range(10571):
    if int(bat['start_date'][0].split('-')[0]) >2003:
        print('yess')
# Out:
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# ...

# %% [markdown]
# # new data Batting

# %%
odibat = pd.read_csv(r'E:\Deep_Learning\Projects\7-Hackathon_INDVPAK\Men ODI Player Innings Stats - 21st Century.csv\Men ODI Player Innings Stats - 21st Century.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 odibat = pd.read_csv(r'E:\Deep_Learning\Projects\7-Hackathon_INDVPAK\Men ODI Player Innings Stats - 21st Century.csv\Men ODI Player Innings Stats - 21st Century.csv')
#
# ...

# %%
odibat.shape
# Out:
# (327328, 28)

# %%
odibat.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0         JJ Roy                 180                     180
# 1       AD Hales                 171                     171
# 2         JJ Roy                 162                     162
# 3     AJ Strauss                 158                     158
# 4     AJ Strauss                 154                     154
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    151                  1.0                   0.0
# 1                    166                  1.0                   0.0
# 2                    172                  1.0                   0.0
# 3                    188                  1.0                   0.0
# 4                    201                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                 151                     16                      5
# ...

# %%
odibat.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
odibat.drop(columns=['Innings Runs Scored Num','Innings Overs Bowled','Innings Bowled Flag','Innings Maidens Bowled',
                      'Innings Runs Conceded','Innings Wickets Taken','4 Wickets','5 Wickets','10 Wickets',
                      'Innings Wickets Taken Buckets','Innings Economy Rate'],axis=1,inplace=True)

# %%
odibat.head()
# Out:
#   Innings Player Innings Runs Scored Innings Minutes Batted  \
# 0         JJ Roy                 180                    151
# 1       AD Hales                 171                    166
# 2         JJ Roy                 162                    172
# 3     AJ Strauss                 158                    188
# 4     AJ Strauss                 154                    201
#
#    Innings Batted Flag  Innings Not Out Flag Innings Balls Faced  \
# 0                  1.0                   0.0                 151
# 1                  1.0                   0.0                 122
# 2                  1.0                   0.0                 118
# 3                  1.0                   0.0                 145
# 4                  1.0                   0.0                 140
#
#   Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate  \
# 0                     16                      5                      119.20
# ...

# %%
odibat['Innings Player'].unique()
# Out:
# array(['JJ Roy', 'AD Hales', 'AJ Strauss', ..., 'Mohibullah Oryakhel',
#        'Rokhan Barakzai', 'Zahir Khan'], dtype=object)

# %%
odibat1 = odibat[(odibat['Country'] == 'India') | (odibat['Country'] == 'Australia')]

# %%
odibat1['Country'].unique()
# Out:
# array(['Australia', 'India'], dtype=object)

# %%
odibat1.shape
# Out:
# (66808, 17)

# %%
odibat1.head()
# Out:
#      Innings Player Innings Runs Scored Innings Minutes Batted  \
# 4671      SR Watson                185*                    113
# 4672      ML Hayden                181*                    227
# 4673      DA Warner                 179                    186
# 4674      DA Warner                 178                    164
# 4675       ME Waugh                 173                    199
#
#       Innings Batted Flag  Innings Not Out Flag Innings Balls Faced  \
# 4671                  1.0                   1.0                  96
# 4672                  1.0                   1.0                 166
# 4673                  1.0                   0.0                 128
# 4674                  1.0                   0.0                 133
# 4675                  1.0                   0.0                 148
#
#      Innings Boundary Fours Innings Boundary Sixes  \
# 4671                     15                     15
# 4672                     11                     10
# ...

# %%
odibat1 = odibat1.reset_index()

# %%
odibat['Innings Player'].value_counts()
# Out:
# Innings Player
# DPMD Jayawardene    2301
# KC Sangakkara       2297
# MS Dhoni            2086
# TM Dilshan          1902
# Yuvraj Singh        1729
#                     ...
# Zahir Khan             6
# M Bhanuka              5
# DM Dupavillon          4
# Mohammad Naim          4
# Afif Hossain           4
# Name: count, Length: 1436, dtype: int64

# %%
for i in range(66808):
    
    if odibat1['Innings Player'][i].split()[-1]=='Cummins':
        print(count)
        break
    else:
        count=+1
# Out:
# 1

# %%
odibat['Innings Player'][0].split()[-1]
# Out:
# 'Roy'

# %%
df['Last Name'] = df['player_name'].str.split().str[-1]
odibat1['Last Name'] = odibat1['Innings Player'].str.split().str[-1]

# %%
nbat=  odibat1[odibat1['Last Name'].isin(df['Last Name'])]

# %%
df['player_name'].unique()
# Out:
# array(['Pat Cummins', 'Steve Smith', 'Mitch Marsh', 'David Warner',
#        'Glenn Maxwell', 'Mitchell Starc.', 'Josh Hazlewood',
#        'Rohit Sharma', 'Virat Kohli', 'Mohammed Shami',
#        'Ravichandran Ashwin', 'Marcus Stoinis', 'Travis Head',
#        'Adam Zampa', 'Hardik Pandya', 'Jasprit Bumrah', 'Kuldeep Yadav',
#        'Alex Carey', 'Ravindra Jadeja', 'KL Rahul', 'Marnus Labuschagne',
#        'Shreyas Iyer', 'Shardul Thakur', 'Cameron Green', 'Josh Inglis',
#        'Sean Abbott', 'Shubman Gill', 'Ishan Kishan', 'Suryakumar Yadav',
#        'Mohammed Siraj'], dtype=object)

# %%
nbat['Innings Player'].unique()
# Out:
# array(['DA Warner', 'SPD Smith', 'SE Marsh', 'MP Stoinis', 'TM Head',
#        'M Labuschagne', 'MR Marsh', 'GJ Maxwell', 'AT Carey',
#        'PJ Cummins', 'A Zampa', 'JR Hazlewood', 'SA Abbott', 'RG Sharma',
#        'V Kohli', 'KL Rahul', 'SS Iyer', 'RA Jadeja', 'HH Pandya',
#        'Jai P Yadav', 'R Ashwin', 'Joginder Sharma', 'Mohammed Shami',
#        'SN Thakur', 'Kuldeep Yadav', 'UT Yadav', 'I Sharma', 'MM Sharma',
#        'JJ Bumrah', 'Shubman Gill', 'J Yadav', 'R Sharma', 'KV Sharma',
#        'Mohammed Siraj'], dtype=object)

# %%
hitlist = ['Jai P Yadav','Joginder Sharma','I Sharma','MM Sharma','J Yadav','KV Sharma','SE Marsh','R Sharma','UT Yadav']

# %%
nbat = nbat[~nbat['Innings Player'].isin(hitlist)]

# %%
nbat['Innings Player'].unique()
# Out:
# array(['DA Warner', 'SPD Smith', 'MP Stoinis', 'TM Head', 'M Labuschagne',
#        'MR Marsh', 'GJ Maxwell', 'AT Carey', 'PJ Cummins', 'A Zampa',
#        'JR Hazlewood', 'SA Abbott', 'RG Sharma', 'V Kohli', 'KL Rahul',
#        'SS Iyer', 'RA Jadeja', 'HH Pandya', 'R Ashwin', 'Mohammed Shami',
#        'SN Thakur', 'Kuldeep Yadav', 'JJ Bumrah', 'Shubman Gill',
#        'Mohammed Siraj'], dtype=object)

# %%
nbat.sample()
# Out:
#         index  Innings Player Innings Runs Scored Innings Minutes Batted  \
# 61264  271538  Mohammed Shami                 NaN                    NaN
#
#        Innings Batted Flag  Innings Not Out Flag Innings Balls Faced  \
# 61264                  NaN                   NaN                 NaN
#
#       Innings Boundary Fours Innings Boundary Sixes  \
# 61264                    NaN                    NaN
#
#       Innings Batting Strike Rate Innings Number     Opposition  \
# 61264                         NaN              1  v New Zealand
#
#                 Ground Innings Date Country  50's  100's  \
# 61264  Mount Maunganui   2019/01/28   India   NaN    NaN
#
#       Innings Runs Scored Buckets Last Name
# 61264                         NaN     Shami

# %%
nbat['Innings Balls Faced'].isnull().sum()
# Out:
# 5281

# %%
nbat.shape
# Out:
# (10571, 19)

# %%
nbat.reset_index(inplace=True)

# %%
for i in range(10571):
    if int(nbat['Innings Date'][0].split('/')[0]) >2016:
        print('yess')
# Out:
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# yess
# ...

# %%
odibat1['Innings Player'].unique()
# Out:
# array(['SR Watson', 'ML Hayden', 'DA Warner', 'ME Waugh', 'AC Gilchrist',
#        'RT Ponting', 'SPD Smith', 'A Symonds', 'GJ Bailey', 'AJ Finch',
#        'SE Marsh', 'MP Stoinis', 'DR Martyn', 'PJ Hughes', 'MJ Clarke',
#        'TM Head', 'BJ Hodge', 'DS Lehmann', 'PSP Handscomb',
#        'JP Faulkner', 'AC Voges', 'DJ Hussey', 'TD Paine', 'BJ Haddin',
#        'MEK Hussey', 'M Labuschagne', 'SM Katich', 'CL White',
#        'PJ Forrest', 'UT Khawaja', 'MG Bevan', 'MR Marsh', 'GJ Maxwell',
#        'MS Wade', 'JP Maher', 'PA Jaques', 'NM Coulter-Nile', 'AT Carey',
#        'AJ Turner', 'SR Waugh', 'MJ Cosgrove', 'MG Johnson', 'GB Hogg',
#        'CJ Ferguson', 'JA Burns', 'DJM Short', 'AJ Bichel', 'L Ronchi',
#        'JR Hopes', 'B Lee', 'NM Hauritz', 'MA Starc', 'JW Hastings',
#        'IJ Harvey', 'AC Agar', 'JN Gillespie', 'CA Lynn', 'DT Christian',
#        'RJ Campbell', 'SK Warne', 'PJ Cummins', 'DE Bollinger',
# ...

# %%
nbat.dropna(inplace=True)

# %%
nbat
# Out:
#       level_0   index  Innings Player Innings Runs Scored  \
# 0           2    4673       DA Warner                 179
# 1           3    4674       DA Warner                 178
# 2           5    4676       DA Warner                 173
# 3           7    4678       DA Warner                 166
# 4           9    4680       SPD Smith                 164
# ...       ...     ...             ...                 ...
# 9501    60978  262184       RA Jadeja                 DNB
# 9502    60979  262185       JJ Bumrah                 DNB
# 9503    60980  262186       SN Thakur                 DNB
# 9504    60981  262187  Mohammed Shami                 DNB
# 9505    60983  262189       JJ Bumrah                 DNB
#
#      Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                       186                  1.0                   0.0
# 1                       164                  1.0                   0.0
# ...

# %%
mastarc = odibat1[odibat1['Innings Player']=='MA Starc']
mastarc.shape
# Out:
# (538, 19)

# %%
nbat = nbat._append(mastarc,ignore_index=True)

# %%
nbat.head()
# Out:
#    level_0  index Innings Player Innings Runs Scored Innings Minutes Batted  \
# 0      2.0   4673      DA Warner                 179                    186
# 1      3.0   4674      DA Warner                 178                    164
# 2      5.0   4676      DA Warner                 173                    218
# 3      7.0   4678      DA Warner                 166                    184
# 4      9.0   4680      SPD Smith                 164                    206
#
#    Innings Batted Flag  Innings Not Out Flag Innings Balls Faced  \
# 0                  1.0                   0.0                 128
# 1                  1.0                   0.0                 133
# 2                  1.0                   0.0                 136
# 3                  1.0                   0.0                 147
# 4                  1.0                   0.0                 157
#
#   Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate  \
# ...

# %%
nbat.drop('level_0',axis=1,inplace=True)

# %%
nbat.dropna(inplace=True)

# %%
nbat['Innings Player'].unique().shape
# Out:
# (26,)

# %%
nbat.head()
# Out:
#    index Innings Player Innings Runs Scored Innings Minutes Batted  \
# 0   4673      DA Warner                 179                    186
# 1   4674      DA Warner                 178                    164
# 2   4676      DA Warner                 173                    218
# 3   4678      DA Warner                 166                    184
# 4   4680      SPD Smith                 164                    206
#
#    Innings Batted Flag  Innings Not Out Flag Innings Balls Faced  \
# 0                  1.0                   0.0                 128
# 1                  1.0                   0.0                 133
# 2                  1.0                   0.0                 136
# 3                  1.0                   0.0                 147
# 4                  1.0                   0.0                 157
#
#   Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate  \
# 0                     19                      5                      139.84
# ...

# %%
nbat.shape
# Out:
# (5559, 19)

# %%
nbat.describe()
# Out:
#                index  Innings Batted Flag  Innings Not Out Flag         50's  \
# count    5559.000000          5559.000000           5559.000000  5559.000000
# mean   135291.579421             0.760928              0.152725     0.124303
# std     90766.158252             0.426555              0.359755     0.329957
# min      4673.000000             0.000000              0.000000     0.000000
# 25%     41201.500000             1.000000              0.000000     0.000000
# 50%    147697.000000             1.000000              0.000000     0.000000
# 75%    226138.500000             1.000000              0.000000     0.000000
# max    262189.000000             1.000000              1.000000     1.000000
#
#              100's
# count  5559.000000
# mean      0.058644
# std       0.234978
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
nbat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5559 entries, 0 to 5739
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        5559 non-null   int64
#  1   Innings Player               5559 non-null   object
#  2   Innings Runs Scored          5559 non-null   object
#  3   Innings Minutes Batted       5559 non-null   object
#  4   Innings Batted Flag          5559 non-null   float64
#  5   Innings Not Out Flag         5559 non-null   float64
#  6   Innings Balls Faced          5559 non-null   object
#  7   Innings Boundary Fours       5559 non-null   object
#  8   Innings Boundary Sixes       5559 non-null   object
#  9   Innings Batting Strike Rate  5559 non-null   object
#  10  Innings Number               5559 non-null   object
#  11  Opposition                   5559 non-null   object
#  12  Ground                       5559 non-null   object
# ...

# %% [markdown]
# ### Necessary data type converting

# %%
nbat['Innings Runs Scored'] = nbat['Innings Runs Scored'].str.replace('*', '')
nbat['Innings Runs Scored'] = nbat['Innings Runs Scored'].replace(['DNB', 'TDNB'], np.nan, regex=False)
try:
    nbat['Innings Runs Scored'] = nbat['Innings Runs Scored'].astype('float32')
    nbat['Innings Runs Scored'] = nbat['Innings Runs Scored'].fillna(0).astype('int32')
except ValueError:
    print("Error: Unable to convert 'Innings Runs Scored' to int32. Check for non-numeric values.")

# %%
nbat['Innings Runs Scored'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Minutes Batted'] = nbat['Innings Minutes Batted'].str.replace('-', '')
nbat['Innings Minutes Batted'] = pd.to_numeric(nbat['Innings Minutes Batted'], errors='coerce')
nbat['Innings Minutes Batted'].fillna(0, inplace=True)
nbat['Innings Minutes Batted'] = nbat['Innings Minutes Batted'].astype('int64')

# %%
nbat['Innings Minutes Batted'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Balls Faced'] = nbat['Innings Balls Faced'].str.replace('-', '')
nbat['Innings Balls Faced'] = pd.to_numeric(nbat['Innings Balls Faced'], errors='coerce')
nbat['Innings Balls Faced'].fillna(0, inplace=True)
nbat['Innings Balls Faced'] = nbat['Innings Balls Faced'].astype('int64')

# %%
nbat['Innings Balls Faced'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Boundary Fours'] = nbat['Innings Boundary Fours'].str.replace('-', '')
nbat['Innings Boundary Fours'] = pd.to_numeric(nbat['Innings Boundary Fours'], errors='coerce')
nbat['Innings Boundary Fours'].fillna(0, inplace=True)
nbat['Innings Boundary Fours'] = nbat['Innings Boundary Fours'].astype('int64')

# %%
nbat['Innings Boundary Fours'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Boundary Sixes'] = nbat['Innings Boundary Sixes'].str.replace('-', '')
nbat['Innings Boundary Sixes'] = pd.to_numeric(nbat['Innings Boundary Sixes'], errors='coerce')
nbat['Innings Boundary Sixes'].fillna(0, inplace=True)
nbat['Innings Boundary Sixes'] = nbat['Innings Boundary Sixes'].astype('int64')

# %%
nbat['Innings Boundary Sixes'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Batting Strike Rate'] = nbat['Innings Batting Strike Rate'].str.replace('-', '')
nbat['Innings Batting Strike Rate'] = pd.to_numeric(nbat['Innings Batting Strike Rate'], errors='coerce')
nbat['Innings Batting Strike Rate'].fillna(0, inplace=True)
nbat['Innings Batting Strike Rate'] = nbat['Innings Batting Strike Rate'].astype('int64')

# %%
nbat['Innings Batting Strike Rate'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Number'] = nbat['Innings Number'].str.replace('-', '')
nbat['Innings Number'] = pd.to_numeric(nbat['Innings Number'], errors='coerce')
nbat['Innings Number'].fillna(0, inplace=True)
nbat['Innings Number'] = nbat['Innings Number'].astype('int64')

# %%
nbat['Innings Number'].isnull().sum()
# Out:
# 0

# %%
nbat['Innings Runs Scored Buckets'] = nbat['Innings Runs Scored Buckets'].str.replace('-', '')
nbat['Innings Runs Scored Buckets'] = pd.to_numeric(nbat['Innings Runs Scored Buckets'], errors='coerce')
nbat['Innings Runs Scored Buckets'].fillna(0, inplace=True)
nbat['Innings Runs Scored Buckets'] = nbat['Innings Runs Scored Buckets'].astype('int64')

# %%
nbat['Innings Runs Scored Buckets'].isnull().sum()
# Out:
# 0

# %%
nbat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5559 entries, 0 to 5739
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        5559 non-null   int64
#  1   Innings Player               5559 non-null   object
#  2   Innings Runs Scored          5559 non-null   int32
#  3   Innings Minutes Batted       5559 non-null   int64
#  4   Innings Batted Flag          5559 non-null   float64
#  5   Innings Not Out Flag         5559 non-null   float64
#  6   Innings Balls Faced          5559 non-null   int64
#  7   Innings Boundary Fours       5559 non-null   int64
#  8   Innings Boundary Sixes       5559 non-null   int64
#  9   Innings Batting Strike Rate  5559 non-null   int64
#  10  Innings Number               5559 non-null   int64
#  11  Opposition                   5559 non-null   object
#  12  Ground                       5559 non-null   object
# ...

# %%
nbat.describe()
# Out:
#                index  Innings Runs Scored  Innings Minutes Batted  \
# count    5559.000000          5559.000000             5559.000000
# mean   135291.579421            24.361216               31.414103
# std     90766.158252            35.206972               46.948286
# min      4673.000000             0.000000                0.000000
# 25%     41201.500000             0.000000                0.000000
# 50%    147697.000000             8.000000                9.000000
# 75%    226138.500000            35.000000               42.000000
# max    262189.000000           264.000000              228.000000
#
#        Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced  \
# count          5559.000000           5559.000000          5559.000000
# mean              0.760928              0.152725            26.323260
# std               0.426555              0.359755            34.219883
# min               0.000000              0.000000             0.000000
# ...

# %%
nbat.to_csv('nbat.csv')

# %% [markdown]
# # New Data Balling

# %%
odiball = pd.read_csv(r'E:\Machine_Learning\PROJECTS\Hackathon_INDVPAK\Men ODI Player Innings Stats - 21st Century.csv\Men ODI Player Innings Stats - 21st Century.csv')

# %%
odiball.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0         JJ Roy                 180                     180
# 1       AD Hales                 171                     171
# 2         JJ Roy                 162                     162
# 3     AJ Strauss                 158                     158
# 4     AJ Strauss                 154                     154
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    151                  1.0                   0.0
# 1                    166                  1.0                   0.0
# 2                    172                  1.0                   0.0
# 3                    188                  1.0                   0.0
# 4                    201                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                 151                     16                      5
# ...

# %%
odiball.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
odiball.drop(columns=['Innings Runs Scored','Innings Runs Scored Num',
       'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
       'Innings Balls Faced', 'Innings Boundary Fours',
       'Innings Boundary Sixes', 'Innings Batting Strike Rate',
       'Innings Number','Innings Runs Scored Buckets'],axis=1,inplace=True)

# %%
odiball.head()
# Out:
#   Innings Player    Opposition      Ground Innings Date  Country  50's  100's  \
# 0         JJ Roy   v Australia   Melbourne   2018/01/14  England   0.0    1.0
# 1       AD Hales    v Pakistan  Nottingham   2016/08/30  England   0.0    1.0
# 2         JJ Roy   v Sri Lanka    The Oval   2016/06/29  England   0.0    1.0
# 3     AJ Strauss       v India   Bengaluru   2011/02/27  England   0.0    1.0
# 4     AJ Strauss  v Bangladesh  Birmingham   2010/07/12  England   0.0    1.0
#
#   Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  \
# ...

# %%
odiball.drop(columns=['100\'s','50\'s'],inplace=True)

# %%
odiball.head()
# Out:
#   Innings Player    Opposition      Ground Innings Date  Country  \
# 0         JJ Roy   v Australia   Melbourne   2018/01/14  England
# 1       AD Hales    v Pakistan  Nottingham   2016/08/30  England
# 2         JJ Roy   v Sri Lanka    The Oval   2016/06/29  England
# 3     AJ Strauss       v India   Bengaluru   2011/02/27  England
# 4     AJ Strauss  v Bangladesh  Birmingham   2010/07/12  England
#
#   Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  \
# 0                   NaN                   NaN        NaN        NaN
# ...

# %%
df['player_name'].unique()
# Out:
# array(['Pat Cummins', 'Steve Smith', 'Mitch Marsh', 'David Warner',
#        'Glenn Maxwell', 'Mitchell Starc.', 'Josh Hazlewood',
#        'Rohit Sharma', 'Virat Kohli', 'Mohammed Shami',
#        'Ravichandran Ashwin', 'Marcus Stoinis', 'Travis Head',
#        'Adam Zampa', 'Hardik Pandya', 'Jasprit Bumrah', 'Kuldeep Yadav',
#        'Alex Carey', 'Ravindra Jadeja', 'KL Rahul', 'Marnus Labuschagne',
#        'Shreyas Iyer', 'Shardul Thakur', 'Cameron Green', 'Josh Inglis',
#        'Sean Abbott', 'Shubman Gill', 'Ishan Kishan', 'Suryakumar Yadav',
#        'Mohammed Siraj'], dtype=object)

# %%
bowlers = ['Glenn Maxwell','Mitchell Starc.', 'Josh Hazlewood','Mohammed Shami',
       'Ravichandran Ashwin', 'Marcus Stoinis','Adam Zampa', 'Hardik Pandya', 'Jasprit Bumrah', 'Kuldeep Yadav'
          ,'Ravindra Jadeja','Shardul Thakur', 'Cameron Green','Sean Abbott','Mohammed Siraj']

# %%
df['Last Name'] = df['player_name'].str.split().str[-1]
odiball['Last Name'] = odiball['Innings Player'].str.split().str[-1]

# %%
nball=  odiball[odiball['Last Name'].isin(df['Last Name'])]

# %%
nball['Innings Player'].unique()
# Out:
# array(['DA Warner', 'SPD Smith', 'SE Marsh', 'MP Stoinis', 'TM Head',
#        'M Labuschagne', 'MR Marsh', 'GJ Maxwell', 'AT Carey',
#        'PJ Cummins', 'A Zampa', 'JR Hazlewood', 'SA Abbott', 'GC Smith',
#        'KJ Abbott', 'DS Smith', 'DR Smith', 'ML Cummins', 'RG Sharma',
#        'V Kohli', 'KL Rahul', 'SS Iyer', 'RA Jadeja', 'HH Pandya',
#        'Jai P Yadav', 'R Ashwin', 'Joginder Sharma', 'Mohammed Shami',
#        'SN Thakur', 'Kuldeep Yadav', 'UT Yadav', 'I Sharma', 'MM Sharma',
#        'JJ Bumrah', 'Shubman Gill', 'J Yadav', 'R Sharma', 'KV Sharma',
#        'Mohammed Siraj', 'CJ Smith', 'M Smith', 'ZE Green', 'CJO Smith',
#        'RAJ Smith'], dtype=object)

# %%
hitlist = ['Jai P Yadav','Joginder Sharma','I Sharma','MM Sharma','J Yadav','KV Sharma','SE Marsh','R Sharma','UT Yadav']

# %%
nball = nball[~nball['Innings Player'].isin(hitlist)]

# %%
nball['Innings Player'].unique()
# Out:
# array(['DA Warner', 'SPD Smith', 'MP Stoinis', 'TM Head', 'M Labuschagne',
#        'MR Marsh', 'GJ Maxwell', 'AT Carey', 'PJ Cummins', 'A Zampa',
#        'JR Hazlewood', 'SA Abbott', 'GC Smith', 'KJ Abbott', 'DS Smith',
#        'DR Smith', 'ML Cummins', 'RG Sharma', 'V Kohli', 'KL Rahul',
#        'SS Iyer', 'RA Jadeja', 'HH Pandya', 'R Ashwin', 'Mohammed Shami',
#        'SN Thakur', 'Kuldeep Yadav', 'JJ Bumrah', 'Shubman Gill',
#        'Mohammed Siraj', 'CJ Smith', 'M Smith', 'ZE Green', 'CJO Smith',
#        'RAJ Smith'], dtype=object)

# %%
hitlist2 = ['GC Smith', 'KJ Abbott','DS Smith',
       'DR Smith', 'ML Cummins','CJ Smith', 'M Smith', 'ZE Green', 'CJO Smith',
       'RAJ Smith']

# %%
nball = nball[~nball['Innings Player'].isin(hitlist2)]

# %%
hitlist3 = ['DA Warner', 'SPD Smith','TM Head', 'M Labuschagne',
       'MR Marsh', 'GJ Maxwell', 'AT Carey','RG Sharma', 'V Kohli', 'KL Rahul',
       'SS Iyer','Shubman Gill']

# %%
nball = nball[~nball['Innings Player'].isin(hitlist3)]

# %%
nball['Innings Player'].unique()
# Out:
# array(['MP Stoinis', 'PJ Cummins', 'A Zampa', 'JR Hazlewood', 'SA Abbott',
#        'RA Jadeja', 'HH Pandya', 'R Ashwin', 'Mohammed Shami',
#        'SN Thakur', 'Kuldeep Yadav', 'JJ Bumrah', 'Mohammed Siraj'],
#       dtype=object)

# %%
starc = odiball[odiball['Innings Player'].str.split().str[-1]=='Starc']

# %%
nball = nball._append(starc,ignore_index=True)

# %%
nball['Innings Player'].unique()
# Out:
# array(['MP Stoinis', 'PJ Cummins', 'A Zampa', 'JR Hazlewood', 'SA Abbott',
#        'RA Jadeja', 'HH Pandya', 'R Ashwin', 'Mohammed Shami',
#        'SN Thakur', 'Kuldeep Yadav', 'JJ Bumrah', 'Mohammed Siraj',
#        'MA Starc'], dtype=object)

# %%
green = odiball[odiball['Innings Player'].str.split().str[-1]=='Green']

# %%
nball = nball._append(green,ignore_index=True)

# %%
nball.shape
# Out:
# (5072, 16)

# %%
nball.head()
# Out:
#   Innings Player      Opposition     Ground Innings Date    Country  \
# 0     MP Stoinis   v New Zealand   Auckland   2017/01/30  Australia
# 1     MP Stoinis       v England      Perth   2018/01/28  Australia
# 2     MP Stoinis  v South Africa     Hobart   2018/11/11  Australia
# 3     MP Stoinis         v India    Kolkata   2017/09/21  Australia
# 4     MP Stoinis       v England  Melbourne   2018/01/14  Australia
#
#   Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  \
# 0                   NaN                   NaN        NaN        NaN
# ...

# %%
nball.drop('Last Name',axis=1,inplace=True)

# %%
nball.head()
# Out:
#   Innings Player      Opposition     Ground Innings Date    Country  \
# 0     MP Stoinis   v New Zealand   Auckland   2017/01/30  Australia
# 1     MP Stoinis       v England      Perth   2018/01/28  Australia
# 2     MP Stoinis  v South Africa     Hobart   2018/11/11  Australia
# 3     MP Stoinis         v India    Kolkata   2017/09/21  Australia
# 4     MP Stoinis       v England  Melbourne   2018/01/14  Australia
#
#   Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  \
# 0                   NaN                   NaN        NaN        NaN
# ...

# %%
nball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5072 entries, 0 to 5071
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Innings Player                 5072 non-null   object
#  1   Opposition                     5072 non-null   object
#  2   Ground                         5072 non-null   object
#  3   Innings Date                   5072 non-null   object
#  4   Country                        5072 non-null   object
#  5   Innings Overs Bowled           2536 non-null   object
#  6   Innings Bowled Flag            2536 non-null   float64
#  7   Innings Maidens Bowled         2536 non-null   object
#  8   Innings Runs Conceded          2536 non-null   object
#  9   Innings Wickets Taken          2536 non-null   object
#  10  4 Wickets                      2536 non-null   float64
#  11  5 Wickets                      2536 non-null   float64
# ...

# %%
nball.head()
# Out:
#   Innings Player      Opposition     Ground Innings Date    Country  \
# 0     MP Stoinis   v New Zealand   Auckland   2017/01/30  Australia
# 1     MP Stoinis       v England      Perth   2018/01/28  Australia
# 2     MP Stoinis  v South Africa     Hobart   2018/11/11  Australia
# 3     MP Stoinis         v India    Kolkata   2017/09/21  Australia
# 4     MP Stoinis       v England  Melbourne   2018/01/14  Australia
#
#   Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled  \
# 0                  NaN                  NaN                    NaN
# 1                  NaN                  NaN                    NaN
# 2                  NaN                  NaN                    NaN
# 3                  NaN                  NaN                    NaN
# 4                  NaN                  NaN                    NaN
#
#   Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  \
# 0                   NaN                   NaN        NaN        NaN
# ...

# %%
nball.dropna(inplace=True)

# %%
nball.head()
# Out:
#     Innings Player      Opposition      Ground Innings Date    Country  \
# 209   JR Hazlewood   v New Zealand  Birmingham   2017/06/02  Australia
# 210   JR Hazlewood  v South Africa       Perth   2014/11/16  Australia
# 211   JR Hazlewood   v West Indies  Bridgetown   2016/06/26  Australia
# 212     PJ Cummins         v India      Mohali   2019/03/10  Australia
# 213     PJ Cummins       v England    Adelaide   2018/01/26  Australia
#
#     Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled  \
# 209                  9.0                  1.0                      0
# 210                  9.4                  1.0                      2
# 211                  9.4                  1.0                      1
# 212                 10.0                  1.0                      0
# 213                 10.0                  1.0                      2
#
#     Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  \
# ...

# %%
nball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2536 entries, 209 to 5071
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Innings Player                 2536 non-null   object
#  1   Opposition                     2536 non-null   object
#  2   Ground                         2536 non-null   object
#  3   Innings Date                   2536 non-null   object
#  4   Country                        2536 non-null   object
#  5   Innings Overs Bowled           2536 non-null   object
#  6   Innings Bowled Flag            2536 non-null   float64
#  7   Innings Maidens Bowled         2536 non-null   object
#  8   Innings Runs Conceded          2536 non-null   object
#  9   Innings Wickets Taken          2536 non-null   object
#  10  4 Wickets                      2536 non-null   float64
#  11  5 Wickets                      2536 non-null   float64
# ...

# %%
nball['Innings Overs Bowled'] = nball['Innings Overs Bowled'].replace(['DNB', 'TDNB'], np.nan, regex=False)
try:
    nball['Innings Overs Bowled'] = nball['Innings Overs Bowled'].astype('float32')
    nball['Innings Overs Bowled'] = nball['Innings Overs Bowled'].fillna(0).astype('int32')
except ValueError:
    print("Error: Unable to convert 'Innings Runs Scored' to int32. Check for non-numeric values.")

# %%
nball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2536 entries, 209 to 5071
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Innings Player                 2536 non-null   object
#  1   Opposition                     2536 non-null   object
#  2   Ground                         2536 non-null   object
#  3   Innings Date                   2536 non-null   object
#  4   Country                        2536 non-null   object
#  5   Innings Overs Bowled           2536 non-null   int32
#  6   Innings Bowled Flag            2536 non-null   float64
#  7   Innings Maidens Bowled         2536 non-null   object
#  8   Innings Runs Conceded          2536 non-null   object
#  9   Innings Wickets Taken          2536 non-null   object
#  10  4 Wickets                      2536 non-null   float64
#  11  5 Wickets                      2536 non-null   float64
# ...

# %%
nball['Innings Bowled Flag'] = nball['Innings Bowled Flag'].astype('float32')

# %%
nball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2536 entries, 209 to 5071
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Innings Player                 2536 non-null   object
#  1   Opposition                     2536 non-null   object
#  2   Ground                         2536 non-null   object
#  3   Innings Date                   2536 non-null   object
#  4   Country                        2536 non-null   object
#  5   Innings Overs Bowled           2536 non-null   int32
#  6   Innings Bowled Flag            2536 non-null   float32
#  7   Innings Maidens Bowled         2536 non-null   object
#  8   Innings Runs Conceded          2536 non-null   object
#  9   Innings Wickets Taken          2536 non-null   object
#  10  4 Wickets                      2536 non-null   float64
#  11  5 Wickets                      2536 non-null   float64
# ...

# %%
nball['Innings Maidens Bowled'] = nball['Innings Maidens Bowled'].str.replace('-', '')
nball['Innings Maidens Bowled'] = pd.to_numeric(nball['Innings Maidens Bowled'], errors='coerce')
nball['Innings Maidens Bowled'].fillna(0, inplace=True)
nball['Innings Maidens Bowled'] = nball['Innings Maidens Bowled'].astype('int64')

# %%
nball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2536 entries, 209 to 5071
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Innings Player                 2536 non-null   object
#  1   Opposition                     2536 non-null   object
#  2   Ground                         2536 non-null   object
#  3   Innings Date                   2536 non-null   object
#  4   Country                        2536 non-null   object
#  5   Innings Overs Bowled           2536 non-null   int32
#  6   Innings Bowled Flag            2536 non-null   float32
#  7   Innings Maidens Bowled         2536 non-null   int64
#  8   Innings Runs Conceded          2536 non-null   object
#  9   Innings Wickets Taken          2536 non-null   object
#  10  4 Wickets                      2536 non-null   float64
#  11  5 Wickets                      2536 non-null   float64
# ...

# %%
nball['Innings Runs Conceded'] = nball['Innings Runs Conceded'].str.replace('-', '')
nball['Innings Runs Conceded'] = pd.to_numeric(nball['Innings Runs Conceded'], errors='coerce')
nball['Innings Runs Conceded'].fillna(0, inplace=True)
nball['Innings Runs Conceded'] = nball['Innings Runs Conceded'].astype('int64')

# %%
nball['Innings Wickets Taken'] = nball['Innings Wickets Taken'].str.replace('-', '')
nball['Innings Wickets Taken'] = pd.to_numeric(nball['Innings Wickets Taken'], errors='coerce')
nball['Innings Wickets Taken'].fillna(0, inplace=True)
nball['Innings Wickets Taken'] = nball['Innings Wickets Taken'].astype('int64')

# %%
nball.drop('Innings Wickets Taken Buckets',axis=1,inplace=True)

# %%
nball['Innings Economy Rate'] = nball['Innings Economy Rate'].str.replace('-', '')
nball['Innings Economy Rate'] = pd.to_numeric(nball['Innings Economy Rate'], errors='coerce')
nball['Innings Economy Rate'].fillna(0, inplace=True)
nball['Innings Economy Rate'] = nball['Innings Economy Rate'].astype('float64')

# %%
nball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2536 entries, 209 to 5071
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Innings Player          2536 non-null   object
#  1   Opposition              2536 non-null   object
#  2   Ground                  2536 non-null   object
#  3   Innings Date            2536 non-null   object
#  4   Country                 2536 non-null   object
#  5   Innings Overs Bowled    2536 non-null   int32
#  6   Innings Bowled Flag     2536 non-null   float32
#  7   Innings Maidens Bowled  2536 non-null   int64
#  8   Innings Runs Conceded   2536 non-null   int64
#  9   Innings Wickets Taken   2536 non-null   int64
#  10  4 Wickets               2536 non-null   float64
#  11  5 Wickets               2536 non-null   float64
#  12  10 Wickets              2536 non-null   float64
#  13  Innings Economy Rate    2536 non-null   float64
# ...

# %%
nball.to_csv('nball.csv')
